# %% [markdown]
# coin change

# %%
import time

def coin_change(coins, amount):
    # dp[i] = minimum number of coins needed to make amount i
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0

    for i in range(1, amount + 1):
        for coin in coins:
            if coin <= i:
                dp[i] = min(dp[i], dp[i - coin] + 1)

    if dp[amount] == float('inf'):
        return -1
    return dp[amount]


# User input
coins = list(map(int, input("Enter coin denominations separated by spaces: ").split()))
amount = int(input("Enter the target amount: "))

# Measure execution time
start_time = time.perf_counter()

result = coin_change(coins, amount)

end_time = time.perf_counter()

# Display results
if result == -1:
    print("\nChange cannot be made.")
else:
    print("\nMinimum number of coins:", result)

print("Execution Time:", end_time - start_time, "seconds")
print("Time Complexity: O(n × amount)")
print("Space Complexity: O(amount)")
# Out:
# Enter coin denominations separated by spaces: 1 2 5
# Enter the target amount: 11
#
# Minimum number of coins: 3
# Execution Time: 9.992200000397133e-05 seconds
# Time Complexity: O(n × amount)
# Space Complexity: O(amount)

# %% [markdown]
# read me
#
# This program solves the Coin Change problem using Dynamic Programming. It takes coin denominations and a target amount as user input and finds the minimum number of coins. The time complexity is O(n × amount) and the space complexity is O(amount).
