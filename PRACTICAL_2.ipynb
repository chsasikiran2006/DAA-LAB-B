# %% [markdown]
# LINEAR SEARCH

# %%
import time

# Take array input from user
arr = list(map(int, input("Enter numbers separated by spaces: ").split()))

# Take search element
target = int(input("Enter the number to search: "))

print("Array:", arr)

# Start measuring execution time
start_time = time.perf_counter()

# Linear Search
found = False
position = -1

for i in range(len(arr)):
    if arr[i] == target:
        found = True
        position = i
        break

# End measuring execution time
end_time = time.perf_counter()

execution_time = end_time - start_time

# Display result
if found:
    print(f"{target} found at position {position + 1}")
else:
    print(f"{target} not found in the array")

print(f"Execution time: {execution_time:.10f} seconds")

# Complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(n)")
print("Worst Case   : O(n)")

print("\nSpace Complexity: O(1)")
# Out:
# Enter numbers separated by spaces: 10 20 30 40 50
# Enter the number to search: 40
# Array: [10, 20, 30, 40, 50]
# 40 found at position 4
# Execution time: 0.0003272500 seconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(n)
# Worst Case   : O(n)
#
# Space Complexity: O(1)

# %% [markdown]
# BINARY SEARCH

# %%
import time

# Take array input from user
arr = list(map(int, input("Enter numbers separated by spaces: ").split()))

# Binary Search requires a sorted array
arr.sort()

# Take search element
target = int(input("Enter the number to search: "))

print("Sorted array:", arr)

# Start measuring execution time
start_time = time.perf_counter()

# Binary Search
low = 0
high = len(arr) - 1
found = False
position = -1

while low <= high:
    mid = (low + high) // 2

    if arr[mid] == target:
        found = True
        position = mid
        break
    elif arr[mid] < target:
        low = mid + 1
    else:
        high = mid - 1

# End measuring execution time
end_time = time.perf_counter()

execution_time = end_time - start_time

# Display result
if found:
    print(f"{target} found at position {position + 1}")
else:
    print(f"{target} not found in the array")

print(f"Execution time: {execution_time:.10f} seconds")

# Complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(log n)")
print("Worst Case   : O(log n)")

print("\nSpace Complexity: O(1)")
# Out:
# Enter numbers separated by spaces: 20 30 40 50 30 10
# Enter the number to search: 50
# Sorted array: [10, 20, 30, 30, 40, 50]
# 50 found at position 6
# Execution time: 0.0002987690 seconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(log n)
# Worst Case   : O(log n)
#
# Space Complexity: O(1)
